# %% [markdown]
# # CHAPTER 3 - DESCRIBING DATA WITH STATISTICS

# %%
import statistics

# %%
shortlist = [4, 2, 1, 3, 4]

# %%
shortlist
# Out:
# [4, 2, 1, 3, 4]

# %%
statistics.mean(shortlist)
# Out:
# 2.8

# %%
statistics.median(shortlist)
# Out:
# 3

# %%
statistics.mode(shortlist)
# Out:
# 4

# %%
dataset = [7, 8, 9, 2, 10, 9, 9, 9, 9, 4, 5, 6, 1, 5, 6, 7, 8, 6, 1]

# %%
statistics.mean(dataset)
# Out:
# 6.368421052631579

# %%
statistics.median(dataset)
# Out:
# 7

# %%
statistics.mode(dataset)
# Out:
# 9

# %%
import pandas as pd

# %%
dataset = pd.Series(dataset)

# %%
dataset
# Out:
# 0      7
# 1      8
# 2      9
# 3      2
# 4     10
# 5      9
# 6      9
# 7      9
# 8      9
# 9      4
# 10     5
# 11     6
# 12     1
# 13     5
# 14     6
# 15     7
# 16     8
# 17     6
# 18     1
# dtype: int64

# %%
dataset.value_counts(sort=False)
# Out:
# 1     2
# 2     1
# 4     1
# 5     2
# 6     3
# 7     2
# 8     2
# 9     5
# 10    1
# dtype: int64

# %%
dataset.mean()
# Out:
# 6.368421052631579

# %%
dataset.median()
# Out:
# 7.0

# %%
dataset.mode()
# Out:
# 0    9
# dtype: int64

# %% [markdown]
# ## MEASURING THE DISPERSION

# %%
dataset.std()
# Out:
# 2.7930573912190337

# %%
dataset.var()
# Out:
# 7.801169590643275

# %% [markdown]
# ## CALCULATING THE CORRELATION BETWEEN TWO DATA SETS

# %%
high_school_grades = [90, 92, 95, 96, 87, 87, 90, 95, 98, 96]

# %%
college_admission_test_scores = [85, 87, 86, 97, 96, 88, 89, 98, 98, 87]

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(high_school_grades, college_admission_test_scores)
plt.xlabel('High school grades')
plt.ylabel('College admission test scores')
# Out:
# Text(0, 0.5, 'College admission test scores')

# %%
high_school_grades = [83, 85, 84, 96, 94, 86, 87, 97, 97, 85]

# %%
college_admission_test_scores = [85, 87, 86, 97, 96, 88, 89, 98, 98, 87]

# %%
plt.scatter(high_school_grades, college_admission_test_scores)
plt.xlabel('High school grades')
plt.ylabel('College admission test scores')
# Out:
# Text(0, 0.5, 'College admission test scores')

# %%
import pandas as pd

# %%
X1 = [10.0, 8.0, 13.0, 9.0, 11.0, 14.0, 6.0, 4.0, 12.0, 7.0, 5.0]
Y1 = [8.04, 6.95, 7.58, 8.81, 8.33, 9.96, 7.24, 4.26, 10.84, 4.82, 5.68]

# %%
X2 = [10.0, 8.0, 13.0, 9.0, 11.0, 14.0, 6.0, 4.0, 12.0, 7.0, 5.0]
Y2 = [9.14, 8.14, 8.74, 8.77, 9.26, 8.10, 6.13, 3.10, 9.13, 7.26, 4.74]

# %%
X3 = [10.0, 8.0, 13.0, 9.0, 11.0, 14.0, 6.0, 4.0, 12.0, 7.0, 5.0]
Y3 = [7.46, 6.77, 12.74, 7.11, 7.81, 8.84, 6.08, 5.39, 8.15, 6.42, 5.73]

# %%
X4 = [8.0, 8.0, 8.0, 8.0, 8.0, 8.0, 8.0, 19.0, 8.0, 8.0, 8.0]
Y4 = [6.58, 5.76, 7.71, 8.84, 8.47, 7.04, 5.25, 12.50, 5.56, 7.91, 6.89]

# %%
dataset = pd.DataFrame({'X1' : X1,
                        'Y1' : Y1,
                        'X2' : X2,
                        'Y2' : Y2,
                        'X3' : X3,
                        'Y3' : Y3,
                        'X4' : X4,
                        'Y4' : Y4})

# %%
dataset
# Out:
#       X1     Y1    X2    Y2    X3     Y3    X4     Y4
# 0   10.0   8.04  10.0  9.14  10.0   7.46   8.0   6.58
# 1    8.0   6.95   8.0  8.14   8.0   6.77   8.0   5.76
# 2   13.0   7.58  13.0  8.74  13.0  12.74   8.0   7.71
# 3    9.0   8.81   9.0  8.77   9.0   7.11   8.0   8.84
# 4   11.0   8.33  11.0  9.26  11.0   7.81   8.0   8.47
# 5   14.0   9.96  14.0  8.10  14.0   8.84   8.0   7.04
# 6    6.0   7.24   6.0  6.13   6.0   6.08   8.0   5.25
# 7    4.0   4.26   4.0  3.10   4.0   5.39  19.0  12.50
# 8   12.0  10.84  12.0  9.13  12.0   8.15   8.0   5.56
# 9    7.0   4.82   7.0  7.26   7.0   6.42   8.0   7.91
# 10   5.0   5.68   5.0  4.74   5.0   5.73   8.0   6.89

# %%
dataset.columns
# Out:
# Index(['X1', 'Y1', 'X2', 'Y2', 'X3', 'Y3', 'X4', 'Y4'], dtype='object')

# %%
grupos = ['A', 'A', 'B', 'B','C', 'C', 'D', 'D']

# %%
index = list(zip(grupos, dataset.columns))

# %%
index
# Out:
# [('A', 'X1'),
#  ('A', 'Y1'),
#  ('B', 'X2'),
#  ('B', 'Y2'),
#  ('C', 'X3'),
#  ('C', 'Y3'),
#  ('D', 'X4'),
#  ('D', 'Y4')]

# %%
index = pd.MultiIndex.from_tuples(index)

# %%
index
# Out:
# MultiIndex([('A', 'X1'),
#             ('A', 'Y1'),
#             ('B', 'X2'),
#             ('B', 'Y2'),
#             ('C', 'X3'),
#             ('C', 'Y3'),
#             ('D', 'X4'),
#             ('D', 'Y4')],
#            )

# %%
dataset.columns = index

# %%
dataset
# Out:
#        A            B           C            D
#       X1     Y1    X2    Y2    X3     Y3    X4     Y4
# 0   10.0   8.04  10.0  9.14  10.0   7.46   8.0   6.58
# 1    8.0   6.95   8.0  8.14   8.0   6.77   8.0   5.76
# 2   13.0   7.58  13.0  8.74  13.0  12.74   8.0   7.71
# 3    9.0   8.81   9.0  8.77   9.0   7.11   8.0   8.84
# 4   11.0   8.33  11.0  9.26  11.0   7.81   8.0   8.47
# 5   14.0   9.96  14.0  8.10  14.0   8.84   8.0   7.04
# 6    6.0   7.24   6.0  6.13   6.0   6.08   8.0   5.25
# 7    4.0   4.26   4.0  3.10   4.0   5.39  19.0  12.50
# 8   12.0  10.84  12.0  9.13  12.0   8.15   8.0   5.56
# 9    7.0   4.82   7.0  7.26   7.0   6.42   8.0   7.91
# 10   5.0   5.68   5.0  4.74   5.0   5.73   8.0   6.89

# %%
dataset.describe().round(2)
# Out:
#            A             B             C             D
#           X1     Y1     X2     Y2     X3     Y3     X4     Y4
# count  11.00  11.00  11.00  11.00  11.00  11.00  11.00  11.00
# mean    9.00   7.50   9.00   7.50   9.00   7.50   9.00   7.50
# std     3.32   2.03   3.32   2.03   3.32   2.03   3.32   2.03
# min     4.00   4.26   4.00   3.10   4.00   5.39   8.00   5.25
# 25%     6.50   6.32   6.50   6.70   6.50   6.25   8.00   6.17
# 50%     9.00   7.58   9.00   8.14   9.00   7.11   8.00   7.04
# 75%    11.50   8.57  11.50   8.95  11.50   7.98   8.00   8.19
# max    14.00  10.84  14.00   9.26  14.00  12.74  19.00  12.50

# %%
dataset.corr().round(2)
# Out:
#          A           B           C           D
#         X1    Y1    X2    Y2    X3    Y3    X4    Y4
# A X1  1.00  0.82  1.00  0.82  1.00  0.82 -0.50 -0.31
#   Y1  0.82  1.00  0.82  0.75  0.82  0.47 -0.53 -0.49
# B X2  1.00  0.82  1.00  0.82  1.00  0.82 -0.50 -0.31
#   Y2  0.82  0.75  0.82  1.00  0.82  0.59 -0.72 -0.48
# C X3  1.00  0.82  1.00  0.82  1.00  0.82 -0.50 -0.31
#   Y3  0.82  0.47  0.82  0.59  0.82  1.00 -0.34 -0.16
# D X4 -0.50 -0.53 -0.50 -0.72 -0.50 -0.34  1.00  0.82
#   Y4 -0.31 -0.49 -0.31 -0.48 -0.31 -0.16  0.82  1.00

# %%
dataset['A'].plot.scatter(x='X1', y='Y1')
# Out:
# <AxesSubplot:xlabel='X1', ylabel='Y1'>

# %%
dataset['B'].plot.scatter(x='X2', y='Y2')
# Out:
# <AxesSubplot:xlabel='X2', ylabel='Y2'>

# %%
dataset['C'].plot.scatter(x='X3', y='Y3')
# Out:
# <AxesSubplot:xlabel='X3', ylabel='Y3'>

# %%
dataset['D'].plot.scatter(x='X4', y='Y4')
# Out:
# <AxesSubplot:xlabel='X4', ylabel='Y4'>
